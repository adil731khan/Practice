# %%
import matplotlib.pyplot as plt
day=[1,2,3,4,5]
sale1=[20,50,60,80,90]
sale2=[30,40,50,90,120]
plt.plot(day,sale1,marker="o",label="sale1",linestyle="-.",linewidth="2",color="blue")
plt.plot(day,sale2,marker="s",label="sale2",linestyle="-",linewidth="2",color="green")
plt.title("day and sales")
plt.xlabel("day")
plt.ylabel("sale")
plt.legend()
plt.grid(True)
plt.show()

# %%
day=[1,2,3,4,5]
sale1=[20,50,60,80,90]
plt.figure(figsize=(12,5))
plt.plot(day,sale1,marker="d",label="sale1",linestyle="-.",linewidth="2",color="blue")
plt.title("day and sales")
plt.xlabel("day")
plt.ylabel("sale")
plt.grid(True)
#plt.legend()
plt.show()

# %%
week=[1,2,3,4,5]
temp=[33,44,32,49,54]
plt.plot(week,temp,marker="o")
plt.title("week and temperature")
plt.xlabel("week")
plt.ylabel("temp in %")
plt.grid(True)
plt.show()

# %%
month=["jan","feb","mar","apr","may"]
rf=[15,12,16,10,11]
plt.plot(month,rf,marker="s",linestyle="-.")
plt.title("month and rainfall")
plt.xlabel("month")
plt.ylabel("rainfall in %age")
plt.grid()
plt.show()

# %%
subject=["phy","chem","cs","it","pps","coa"]
marks1=[98,55,66,48,92,96]
marks2=[99,85,76,52,68,78]
plt.figure(figsize=(10,3))
plt.plot(subject,marks1,label="student1",marker="d",linestyle="-",color="blue")
plt.plot(subject,marks2,label="student2",marker="o",linestyle="--",color="red")
plt.title("student subject and marks")
plt.xlabel("subject")
plt.ylabel("marks")
plt.legend()
plt.grid()
plt.show()

# %%
day=[1,2,3,4,5,6,7]
co=[50,45,90,60,45,50,51]
colors=["red","blue","green","purple","orange"]
plt.figure(figsize=(5,3))
plt.bar(day,co,color=colors)
plt.title("electricity consumption in a week")
plt.xlabel("day")
plt.ylabel("consumption in unit")
plt.grid(axis="y")
plt.show()

# %%
day=[1,2,3,4,5,6,7]
co=[50,45,90,60,45,50,51]
explode=[0,0,0.2,0,0,0,0]
plt.pie(co,labels=day,autopct="%1.2f%%",explode=explode,shadow=True)
plt.title("electricity consumption in a week")
plt.grid(axis="y")
plt.show()

# %%
month=["jan","feb","mar","apr"]
exp=[20000,15000,12000,18000]
plt.pie(exp,labels=month,autopct="%1.2f%%")#use autopct for %age
plt.title("monthly expenses")
plt.show()

# %%
cor=["cse","AL","IT","CY"]
per=[88,78,96,58]
plt.pie(per,labels=cor,autopct="%1.2f%%",explode=[0,0,0.2,0])#to highlight slice use explode
plt.title("percentage course")
plt.show()

# %%
cor=["cse","AL","IT","CY"]
per=[88,78,96,58]
plt.pie(per,labels=cor,autopct="%1.2f%%",wedgeprops={"width":0.5})#for donut wedgeprops
plt.title("percentage course")
plt.show()

# %%
day=[1,2,3,4,5,6,7]
co=[50,45,90,60,45,50,51]
plt.figure(figsize=(5,3))
plt.scatter(day,co,s=80,marker="o",alpha=1,edgecolors="purple",linewidth=3)#alpha-transparency,s-size of marker
plt.title("electricity consumption in a week")
plt.xlabel("day")
plt.ylabel("consumption in unit")
plt.grid()
plt.show()

# %%
height=[170,165,139,168,152,169,171]
weight=[50,45,90,60,45,50,51]
plt.figure(figsize=(5,3))
plt.scatter(day,co,s=80,marker="o",alpha=1,edgecolors="purple",linewidth=3)#alpha-transparency,s-size of marker
plt.title("electricity consumption in a week")
plt.xlabel("day")
plt.ylabel("consumption in unit")
plt.grid()
plt.show()

# %%
b_height=[170,165,139,168,152,169,171]
b_weight=[50,45,90,60,45,50,51]
g_height=[153,145,169,148,182,179,161]
g_weight=[55,40,85,68,65,40,51]
plt.scatter(b_height,b_weight,label="b",marker="o",alpha=1,edgecolors="purple",linewidth=3)#alpha-transparency,s-size of marker
plt.scatter(g_height,g_weight,label="g",marker="^",alpha=1,edgecolors="red",linewidth=3)
plt.title("electricity consumption in a week")
plt.xlabel("height")
plt.ylabel("weight")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Outliers= The value that effect the mean or other result beecause of either too much or too min value is called Outlier
# # eg:-[51 42 38 <Q1  40 50 <medianQ2  180 45 <Q3  50 48 49]--here 180 is outlier
# ## Q1=25% of value
# ## Q2=50% of value
# ## Q3=75% of value

# %%
#month=["jan","feb","mar","apr","may"]
rf=[15,12,16,25,10,11]
rf2=[10,22,12,35,18,12]
plt.boxplot([rf,rf2],labels=["RF","RF2"])
plt.title("month and rainfall")
plt.ylabel("rainfall in %age")

plt.grid()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13584\4098999112.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([rf,rf2],labels=["RF","RF2"])

# %%
rf2=[10,22,12,35,18,12]
plt.boxplot(rf2,showfliers=False,labels=["rf2"])#showfliers to hide outliers
plt.title("month and rainfall")
plt.ylabel("rainfall in %age")

plt.grid()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13584\142235289.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(rf2,showfliers=False,labels=["rf2"])#showfliers to hide outliers

# %%
slry=[80000,90000,75000,120000,45000,66000]
plt.boxplot(slry)
plt.grid()
plt.show()

# %%
s1=[92,85,93,87,78]
s2=[67,95,73,77,68]
s3=[73,83,97,67,98]
plt.boxplot([s1,s2,s3],labels=["S1","S2","S3"])
plt.grid()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13584\3841150211.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([s1,s2,s3],labels=["S1","S2","S3"])

# %%
slry=[80000,90000,75000,120000,45000,66000]
plt.boxplot(slry,vert=False)
plt.grid()
plt.show()

# %%
slry=[80000,90000,75000,120000,45000,66000]
plt.boxplot(slry,showfliers=False)
plt.grid()
plt.show()

# %% [markdown]
# ## cleaning and modifying data to make it useful for future use is called Data Preprocessing.

# %% [markdown]
# # import sweetviz as sv
# # rep=sv.analyze(df)
# # rep.how_html("file name")    for EDA

# %%
import sweetviz as sv
import pandas as pd

# %%
df=pd.read_csv("mtcars.csv")
report=sv.analyze(df)
report.show_html("report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
